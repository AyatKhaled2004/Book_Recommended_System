# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

book = pd.read_csv(
    'BX-Books.csv',
    sep=";",
    on_bad_lines='skip',   # بدل error_bad_lines
    encoding="latin-1"
)
# Out:
# C:\Users\ayat1\AppData\Local\Temp\ipykernel_15288\1354235714.py:3: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   book = pd.read_csv(

# %%
book.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
book.shape
# Out:
# (271360, 8)

# %%
book.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
book=book[['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
       'Image-URL-S']]

# %%
book.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
book.rename(columns={
'Book-Title':'Title'
    ,
    'Book-Author':'Author'
    , 
    'Year-Of-Publication':'Year'
    , 
    
       'Image-URL-S':'Image_url'
    
},inplace=True)

# %%
# users=pd.read_csv("BX-Users.csv",encoding="latin-1",on_bad_lines="skip",sep="")
import pandas as pd

user = pd.read_csv(
    'BX-Users.csv',
    sep=";",
    on_bad_lines='skip',   # بدل error_bad_lines
    encoding="latin-1"
)

# %%
user.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
import pandas as pd

rating = pd.read_csv(
    'BX-Book-Ratings.csv',
    sep=";",
    on_bad_lines='skip',   # بدل error_bad_lines
    encoding="latin-1"
)

# %%
rating.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
rating['User-ID'].value_counts()
# Out:
# User-ID
# 11676     13602
# 198711     7550
# 153662     6109
# 98391      5891
# 35859      5850
#           ...
# 119573        1
# 276706        1
# 276697        1
# 276679        1
# 276676        1
# Name: count, Length: 105283, dtype: int64

# %%
x=rating['User-ID'].value_counts() >200
x
# Out:
# User-ID
# 11676      True
# 198711     True
# 153662     True
# 98391      True
# 35859      True
#           ...
# 119573    False
# 276706    False
# 276697    False
# 276679    False
# 276676    False
# Name: count, Length: 105283, dtype: bool

# %%
x[x].shape
# Out:
# (899,)

# %%
y=x[x].index

# %%
y
# Out:
# Index([ 11676, 198711, 153662,  98391,  35859, 212898, 278418,  76352, 110973,
#        235105,
#        ...
#        116122,  44296,  28634,  59727,  73681, 274808, 188951,   9856, 155916,
#        268622],
#       dtype='int64', name='User-ID', length=899)

# %%
rating=rating[rating['User-ID'].isin(y)]

# %%
rating.head()
# Out:
#       User-ID        ISBN  Book-Rating
# 1456   277427  002542730X           10
# 1457   277427  0026217457            0
# 1458   277427  003008685X            8
# 1459   277427  0030615321            0
# 1460   277427  0060002050            0

# %%
rating_with_boooks=rating.merge(book,on='ISBN')
rating_with_boooks
# Out:
#         User-ID        ISBN  Book-Rating  \
# 0        277427  002542730X           10
# 1        277427  0026217457            0
# 2        277427  003008685X            8
# 3        277427  0030615321            0
# 4        277427  0060002050            0
# ...         ...         ...          ...
# 487666   275970  1931868123            0
# 487667   275970  3411086211           10
# 487668   275970  3829021860            0
# 487669   275970  4770019572            0
# 487670   275970  9626340762            8
#
#                                                     Title  \
# 0       Politically Correct Bedtime Stories: Modern Ta...
# 1                      Vegetarian Times Complete Cookbook
# 2                                                Pioneers
# 3        Ask for May, Settle for June (A Doonesbury book)
# 4                       On a Wicked Dawn (Cynster Novels)
# ...                                                   ...
# ...

# %%
num_rating=rating_with_boooks.groupby('Title')['Book-Rating'].count().reset_index()

# %%
num_rating
# Out:
#                                                     Title  Book-Rating
# 0        A Light in the Storm: The Civil War Diary of ...            2
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Beyond IBM: Leadership Marketing and Finance ...            1
# 4        Clifford Visita El Hospital (Clifford El Gran...            1
# ...                                                   ...          ...
# 160264  Ã?Â?ber die Pflicht zum Ungehorsam gegen den S...            3
# 160265                                      Ã?Â?lpiraten.            1
# 160266                     Ã?Â?rger mit Produkt X. Roman.            1
# 160267                              Ã?Â?stlich der Berge.            1
# 160268                                  Ã?Â?thique en toc            1
#
# [160269 rows x 2 columns]

# %%
num_rating.rename(columns={'Book-Rating':'num_of_ratings'},inplace=True)

# %%
num_rating
# Out:
#                                                     Title  num_of_ratings
# 0        A Light in the Storm: The Civil War Diary of ...               2
# 1                                   Always Have Popsicles               1
# 2                    Apple Magic (The Collector's series)               1
# 3        Beyond IBM: Leadership Marketing and Finance ...               1
# 4        Clifford Visita El Hospital (Clifford El Gran...               1
# ...                                                   ...             ...
# 160264  Ã?Â?ber die Pflicht zum Ungehorsam gegen den S...               3
# 160265                                      Ã?Â?lpiraten.               1
# 160266                     Ã?Â?rger mit Produkt X. Roman.               1
# 160267                              Ã?Â?stlich der Berge.               1
# 160268                                  Ã?Â?thique en toc               1
#
# [160269 rows x 2 columns]

# %%
final_rating=rating_with_boooks.merge(num_rating,on='Title')

# %%
final_rating
# Out:
#         User-ID        ISBN  Book-Rating  \
# 0        277427  002542730X           10
# 1        277427  0026217457            0
# 2        277427  003008685X            8
# 3        277427  0030615321            0
# 4        277427  0060002050            0
# ...         ...         ...          ...
# 487666   275970  1931868123            0
# 487667   275970  3411086211           10
# 487668   275970  3829021860            0
# 487669   275970  4770019572            0
# 487670   275970  9626340762            8
#
#                                                     Title  \
# 0       Politically Correct Bedtime Stories: Modern Ta...
# 1                      Vegetarian Times Complete Cookbook
# 2                                                Pioneers
# 3        Ask for May, Settle for June (A Doonesbury book)
# 4                       On a Wicked Dawn (Cynster Novels)
# ...                                                   ...
# ...

# %%
final_rating.shape
# Out:
# (487671, 9)

# %%
final_rating=final_rating[final_rating['num_of_ratings']>=50]

# %%
final_rating.shape
# Out:
# (61853, 9)

# %%
final_rating.rename(columns={
    'Image_url_x': 'Image_url',
    'Image_url_y': 'Image_url'
}, inplace=True)
# Out:
# C:\Users\ayat1\AppData\Local\Temp\ipykernel_15288\691494103.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_rating.rename(columns={

# %%
# for col in final_rating.columns:
    
#  print( final_rating[col].duplicated().sum())

# %%
final_rating = final_rating.drop_duplicates(['User-ID','Title']).reset_index(drop=True)

# %%
final_rating.columns
# Out:
# Index(['User-ID', 'ISBN', 'Book-Rating', 'Title', 'Author', 'Year',
#        'Publisher', 'Image_url', 'num_of_ratings'],
#       dtype='object')

# %%
book_pivot=  final_rating.pivot_table(columns='User-ID',index='Title',values='Book-Rating')
book_pivot
# Out:
# User-ID                                             254     2276    2766    \
# Title
# 1984                                                   9.0     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN    10.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# 84 Charing Cross Road                                  NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# ...

# %%
book_pivot.fillna(0,inplace=True)

# %%
book_pivot
# Out:
# User-ID                                             254     2276    2766    \
# Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
from scipy.sparse import csr_matrix
book_sparse=csr_matrix(book_pivot)

# %%
from sklearn.neighbors import NearestNeighbors

# %%
model=NearestNeighbors(algorithm='brute')

# %% [markdown]
# model.fit(book_sparse)

# %%
model.fit(book_sparse)
# Out:
# NearestNeighbors(algorithm='brute')

# %%
distance, suggestion = model.kneighbors(book_pivot.iloc[237,:].values.reshape(1,-1), n_neighbors=6 )

# %%
distance
# Out:
# array([[ 0.        , 67.75691847, 68.05145112, 72.277244  , 75.81556568,
#         76.30203143]])

# %%
suggestion
# Out:
# array([[237, 238, 240, 241, 184, 536]])

# %%
for i in range(len(suggestion)):
    print(book_pivot.index[suggestion[i]])
# Out:
# Index(['Harry Potter and the Chamber of Secrets (Book 2)',
#        'Harry Potter and the Goblet of Fire (Book 4)',
#        'Harry Potter and the Prisoner of Azkaban (Book 3)',
#        'Harry Potter and the Sorcerer's Stone (Book 1)', 'Exclusive',
#        'The Cradle Will Fall'],
#       dtype='object', name='Title')

# %%
book_names = book_pivot.index

# %%
final_rating.columns
# Out:
# Index(['User-ID', 'ISBN', 'Book-Rating', 'Title', 'Author', 'Year',
#        'Publisher', 'Image_url', 'num_of_ratings'],
#       dtype='object')

# %%
np.where(book_pivot.index == '4 Blondes')[0][0]
# Out:
# np.int64(3)

# %%
# ids=np.where(final_rating['Title'=="Harry Potter and the Chamber of Secrets (Book 2)"])[0][0]
match = np.where(final_rating['Title'] == "Harry Potter and the Chamber of Secrets (Book 2)")[0]

if len(match) > 0:
    ids = match[0]

# %%
final_rating.iloc[ids]['Image_url']
# Out:
# 'http://images.amazon.com/images/P/0439064872.01.THUMBZZZ.jpg'

# %%
book_name=[]
for col in suggestion:
    book_name.append(book_pivot.index[col])

# %%
ids_book=[]
for name in book_name[0]:
    # ids=np.where(final_rating['Title'].indes[]==name)[0][0]
    ids = np.where(final_rating['Title'] == name)[0][0]
    ids_book.append(ids)

# %%
for i in ids_book:
    url=final_rating.iloc[i]['Image_url']
    print(url)
# Out:
# http://images.amazon.com/images/P/0439064872.01.THUMBZZZ.jpg
# http://images.amazon.com/images/P/0439139597.01.THUMBZZZ.jpg
# http://images.amazon.com/images/P/0439136369.01.THUMBZZZ.jpg
# http://images.amazon.com/images/P/043936213X.01.THUMBZZZ.jpg
# http://images.amazon.com/images/P/0446604232.01.THUMBZZZ.jpg
# http://images.amazon.com/images/P/0440115450.01.THUMBZZZ.jpg

# %%
import pickle
pickle.dump(model,open('artifacts/model.pkl','wb'))
pickle.dump(book_names,open('artifacts/book_names.pkl','wb'))
pickle.dump(final_rating,open('artifacts/final_rating.pkl','wb'))
pickle.dump(book_pivot,open('artifacts/book_pivot.pkl','wb'))

# %%
def recommend_book(book_name):
    book_id = np.where(book_pivot.index == book_name)[0][0]
    distance, suggestion = model.kneighbors(book_pivot.iloc[book_id,:].values.reshape(1,-1), n_neighbors=6 )
    
    for i in range(len(suggestion)):
            books = book_pivot.index[suggestion[i]]
            for j in books:
                if j == book_name:
                    print(f"You searched '{book_name}'\n")
                    print("The suggestion books are: \n")
                else:
                    print(j)

# %%
book_name = "Harry Potter and the Chamber of Secrets (Book 2)"
recommend_book(book_name)
# Out:
# You searched 'Harry Potter and the Chamber of Secrets (Book 2)'
#
# The suggestion books are:
#
# Harry Potter and the Goblet of Fire (Book 4)
# Harry Potter and the Prisoner of Azkaban (Book 3)
# Harry Potter and the Sorcerer's Stone (Book 1)
# Exclusive
# The Cradle Will Fall
